# %% [markdown]
# # IP Check!

# %%
import urllib.request
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_csv('../dataset/track1.csv')
df = df[df['Status'].astype(str).str.isnumeric()]
df.head()
# Out:
#              Timestamp Method  Protocol Status Referer                Path  \
# 0  2020-08-24 10:00:18    GET  HTTP/1.1    200     "-"  /1000/wp-includes/
# 1  2020-08-24 10:00:18    GET  HTTP/1.1    200     "-"     /1000/wp-login/
# 2  2020-08-24 10:00:18    GET  HTTP/1.1    200     "-"  /1000/wp-register/
# 3  2020-08-24 10:00:18    GET  HTTP/1.1    200     "-"           /1000/wp/
# 4  2020-08-24 10:00:19    GET  HTTP/1.1    200     "-"   /1000/wp-content/
#
#             Host                                                 UA Payload  \
# 0  101.224.32.28  Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv...       -
# 1  101.224.32.28  Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv...       -
# 2  101.224.32.28  Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv...       -
# 3  101.224.32.28  Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv...       -
# 4  101.224.32.28  Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv...       -
#
#     Bytes
# 0  6226.0
# 1  6226.0
# 2  6232.0
# 3  6248.0
# ...

# %% [markdown]
# ## ['Host'] 컬럼에서 nan 값을 발견했다. 무려 4585개!!

# %%
print(len(df[df['Host'].isnull()]))
# Out:
# 4585

# %%
df = df[~df['Host'].isnull()]

# %% [markdown]
# ## 총 3993개의 아이피의 국가를 찾아보자

# %%
ips = df['Host'].unique()
ips = list(ips)
len(ips)
# Out:
# 3993

# %% [markdown]
# ### 중간에 API가 끊길 수 있어서 ['Host']에 값들을 정렬했다.

# %%
ips.sort()

# %%
for ip in ips:
    print(ip)
# Out:
# 0.113.88.147
# 0.116.162.78
# 0.128.52.6
# 0.145.130.53
# 0.155.120.43
# 0.161.135.143
# 0.17.85.75
# 0.175.131.124
# 0.187.54.28
# 0.199.20.91
# 0.242.182.71
# 0.244.217.248
# 0.3.49.39
# 0.40.251.74
# 0.44.15.226
# 0.44.171.213
# 0.60.32.93
# 0.66.220.170
# 0.66.59.153
# 0.75.22.11
# 0.78.171.159
# 1.106.197.60
# 1.11.245.37
# 1.120.230.7
# 1.125.207.185
# 1.132.45.72
# 1.149.169.179
# 1.180.165.53
# 1.190.81.247
# 1.197.83.19
# 1.204.122.80
# 1.216.17.120
# 1.25.19.216
# 1.26.211.249
# 1.27.83.9
# 1.29.137.141
# 1.40.19.112
# 1.41.54.131
# 1.43.209.223
# 1.89.229.23
# 1.94.210.215
# 10.0.96.10
# 10.103.122.128
# 10.11.101.20
# 10.14.56.147
# 10.147.62.145
# 10.161.50.95
# 10.170.191.106
# 10.192.102.163
# 10.20.56.166
# 10.205.141.106
# 10.32.238.75
# 10.4.184.14
# 10.44.89.102
# 10.54.88.179
# 10.64.27.153
# 100.126.145.250
# 100.13.156.69
# 100.138.153.118
# 100.172.132.155
# 100.185.225.112
# 100.200.156.222
# 100.207.146.108
# 100.212.213.67
# 100.227.232.242
# 100.31.90.24
# ...

# %% [markdown]
# ### API가 멈출 때 마다 index 찾아주기

# %%
ips.index('6.54.46.18')
# Out:
# 3289

 '81.226.230.91',
 '55.185.6.120',
 '137.3.55.226',
 '123.252.177.154',
 '178.245.100.17',
 '219.229.163.141',
 '125.197.213.96',
 '73.159.164.232',
 '12.118.38.74',
 '39.112.75.139',
 '77.28.42.72',
 '10.161.50.95',
 '187.82.32.231',
 '187.19.60.109',
 '0.242.182.71',
 '236.117.113.88',
 '198.215.148.228',
 '106.254.46.141',
 '57.40.245.32',
 '109.126.152.174',
 '96.55.243.39',
 '147.245.128.177',
 '79.219.245.90',
 '236.79.11.24',
 '120.59.68.21',
 '97.157.219.191',
 '48.156.186.164',
 '115.112.105.145',
 '34.110.106.4',
 '100.227.232.242',
 '169.161.230.151',
 '34.235.217.86',
 '238.39.228.156',
 '212.254.82.60',
 '113.138.175.149',
 '124.236.155.199',
 '189.59.12.228',
 '219.40.100.241',
 '179.233.243.212',
 '120.126.24.186',
 '152.188.88.120',
 '85.49.64.128',
 '66.112.27.100',
 '155.2.137.36',
 '130.99.247.192',
 '241.166.70.82',
 '83.202.72.192',
 '141.127.187.88',
 '86.75.151.184',
 '77.13.148.197',
 '244.216.242.67',
 '205.254.127.151',
 '127.202.178.51',
 '89.133.124.168',
 '53.119.161.113',
 '240.174.206.196']

# %% [markdown]
# ### 확실히 비정상적인 상위 13개 Host

# %%
topHost = ['101.224.32.28', '231.211.11.16', '137.8.46.133', '100.200.156.222', '112.112.181.134', '188.45.31.10', '188.45.31.20', '188.45.31.30', '188.45.31.40', '14.135.56.110', '14.135.56.120', '14.135.56.130', '14.135.56.140']

# %% [markdown]
# ## Whois API를 사용해서 국가 코드 가져오기
# - xml, json 형태로 가져 올 수 있다.
# - 홈페이지에서 개인키를 발급받아야된다.

# %%
resultPattIps = {}
for i in range(len(pattIps)):    
    ip = pattIps[i]
    whois_key = '개인키'

    query = "http://whois.kisa.or.kr/openapi/whois.jsp?query=" + ip + "&key="+ whois_key + "&answer=json";
    request = urllib.request.urlopen(query).read().decode("utf-8")
    
    resultPattIps[pattIps[i]] = json.loads(request)['whois']['countryCode']
    print(pattIps[i])
    
    
#     WhoIs = []
    
#     WhoIs.append(request['whois']['query'])
#     WhoIs.append(request['whois']['countryCode'])
#     WhoIs.append(request['whois']['korean']['PI']['netinfo']['addr'])
#     WhoIs.append(request['whois']['korean']['PI']['netinfo']['range'])
#     WhoIs.append(request['whois']['korean']['PI']['netinfo']['servName'])
# Out:
# 189.102.137.171
# 166.146.28.109
# 93.139.7.167
# 215.82.66.58
# 62.126.184.49
# 154.183.104.68
# 192.217.106.4
# 33.45.176.173
# 209.163.210.98
# 158.7.116.147
# 157.29.174.233
# 218.186.207.158
# 155.110.66.204
# 113.163.220.14
# 96.220.20.38
# 56.215.113.246
# 253.72.61.176
# 174.212.113.195
# 181.208.169.183
# 231.162.115.137
# 128.60.55.30
# 99.199.46.146
# 230.91.143.108
# 206.52.153.133
# 41.235.176.98
# 110.39.9.172
# 194.48.94.171
# 49.2.124.41
# 13.112.117.158
# 231.229.17.216
# 180.113.58.104
# 53.70.235.161
# 9.27.108.183
# 108.59.199.146
# 58.33.250.234
# 144.218.200.213
# 77.51.208.6
# 119.165.69.87
# 223.7.119.122
# 36.206.166.96
# 207.44.179.175
# 193.102.46.159
# 118.194.121.61
# 185.204.235.94
# 87.232.221.120
# 251.215.60.237
# 122.236.50.249
# 42.154.105.206
# 249.221.133.56
# 31.241.156.71
# 15.120.133.168
# 68.246.216.126
# 241.22.8.121
# 236.162.53.8
# 122.75.246.242
# 210.159.169.113
# 34.69.121.11
# 149.231.211.148
# 114.240.227.197
# 75.98.230.167
# ...

# %%
result1 = result
result1
# Out:
# {'0.113.88.147': 'none',
#  '0.116.162.78': 'none',
#  '0.128.52.6': 'none',
#  '0.145.130.53': 'none',
#  '0.155.120.43': 'none',
#  '0.161.135.143': 'none',
#  '0.17.85.75': 'none',
#  '0.175.131.124': 'none',
#  '0.187.54.28': 'none',
#  '0.199.20.91': 'none',
#  '0.242.182.71': 'none',
#  '0.244.217.248': 'none',
#  '0.3.49.39': 'none',
#  '0.40.251.74': 'none',
#  '0.44.15.226': 'none',
#  '0.44.171.213': 'none',
#  '0.60.32.93': 'none',
#  '0.66.220.170': 'none',
#  '0.66.59.153': 'none',
#  '0.75.22.11': 'none',
#  '0.78.171.159': 'none',
#  '1.106.197.60': 'KR',
#  '1.11.245.37': 'KR',
#  '1.120.230.7': 'AU',
#  '1.125.207.185': 'AU',
#  '1.132.45.72': 'AU',
#  '1.149.169.179': 'AU',
#  '1.180.165.53': 'CN',
#  '1.190.81.247': 'CN',
#  '1.197.83.19': 'CN',
#  '1.204.122.80': 'CN',
#  '1.216.17.120': 'KR',
#  '1.25.19.216': 'CN',
#  '1.26.211.249': 'CN',
#  '1.27.83.9': 'CN',
#  '1.29.137.141': 'CN',
#  '1.40.19.112': 'AU',
#  '1.41.54.131': 'AU',
#  '1.43.209.223': 'AU',
# ...

# %%
result = dict(result1)
result.update(result2)
result
# Out:
# {'0.113.88.147': 'none',
#  '0.116.162.78': 'none',
#  '0.128.52.6': 'none',
#  '0.145.130.53': 'none',
#  '0.155.120.43': 'none',
#  '0.161.135.143': 'none',
#  '0.17.85.75': 'none',
#  '0.175.131.124': 'none',
#  '0.187.54.28': 'none',
#  '0.199.20.91': 'none',
#  '0.242.182.71': 'none',
#  '0.244.217.248': 'none',
#  '0.3.49.39': 'none',
#  '0.40.251.74': 'none',
#  '0.44.15.226': 'none',
#  '0.44.171.213': 'none',
#  '0.60.32.93': 'none',
#  '0.66.220.170': 'none',
#  '0.66.59.153': 'none',
#  '0.75.22.11': 'none',
#  '0.78.171.159': 'none',
#  '1.106.197.60': 'KR',
#  '1.11.245.37': 'KR',
#  '1.120.230.7': 'AU',
#  '1.125.207.185': 'AU',
#  '1.132.45.72': 'AU',
#  '1.149.169.179': 'AU',
#  '1.180.165.53': 'CN',
#  '1.190.81.247': 'CN',
#  '1.197.83.19': 'CN',
#  '1.204.122.80': 'CN',
#  '1.216.17.120': 'KR',
#  '1.25.19.216': 'CN',
#  '1.26.211.249': 'CN',
#  '1.27.83.9': 'CN',
#  '1.29.137.141': 'CN',
#  '1.40.19.112': 'AU',
#  '1.41.54.131': 'AU',
#  '1.43.209.223': 'AU',
# ...

# %% [markdown]
# ### 받아온 결과를 다시 데이터 프레임으로 만든다!

# %%
allIpCountry = pd.DataFrame(list(result.items()),columns = ['ip','country'])

# %%
allIpCountry
# Out:
#                  ip country
# 0      0.113.88.147    none
# 1      0.116.162.78    none
# 2        0.128.52.6    none
# 3      0.145.130.53    none
# 4      0.155.120.43    none
# ...             ...     ...
# 3988  99.68.150.242      US
# 3989   99.71.165.21      US
# 3990   99.83.239.96      US
# 3991    99.97.46.19      US
# 3992   99.98.31.109      US
#
# [3993 rows x 2 columns]

# %%
allIpCountry.to_csv('allIpCountry.csv')

# %%
allCountryValueCount = allIpCountry['country'].value_counts()
allCountryValueCount
# Out:
# US      1534
# none     521
# CN       343
# JP       167
# DE       124
#         ...
# HR         1
# GH         1
# AF         1
# GE         1
# GA         1
# Name: country, Length: 99, dtype: int64

# %%
resultPattIps
# Out:
# {'189.102.137.171': 'BR',
#  '166.146.28.109': 'US',
#  '93.139.7.167': 'HR',
#  '215.82.66.58': 'US',
#  '62.126.184.49': 'GB',
#  '154.183.104.68': 'EG',
#  '192.217.106.4': 'US',
#  '33.45.176.173': 'US',
#  '209.163.210.98': 'US',
#  '158.7.116.147': 'US',
#  '157.29.174.233': 'IT',
#  '218.186.207.158': 'SG',
#  '155.110.66.204': 'US',
#  '113.163.220.14': 'VN',
#  '96.220.20.38': 'US',
#  '56.215.113.246': 'US',
#  '253.72.61.176': 'none',
#  '174.212.113.195': 'US',
#  '181.208.169.183': 'VE',
#  '231.162.115.137': 'none',
#  '128.60.55.30': 'US',
#  '99.199.46.146': 'CA',
#  '230.91.143.108': 'none',
#  '206.52.153.133': 'US',
#  '41.235.176.98': 'EG',
#  '110.39.9.172': 'PK',
#  '194.48.94.171': 'NL',
#  '49.2.124.41': 'AU',
#  '13.112.117.158': 'US',
#  '231.229.17.216': 'none',
#  '180.113.58.104': 'CN',
#  '53.70.235.161': 'DE',
#  '9.27.108.183': 'US',
#  '108.59.199.146': 'US',
#  '58.33.250.234': 'CN',
#  '144.218.200.213': 'AU',
#  '77.51.208.6': 'RU',
# ...

# %%
pattIpCountry = pd.DataFrame(list(resultPattIps.items()),columns = ['ip','country'])
pattIpCountry
# Out:
#                   ip country
# 0    189.102.137.171      BR
# 1     166.146.28.109      US
# 2       93.139.7.167      HR
# 3       215.82.66.58      US
# 4      62.126.184.49      GB
# ..               ...     ...
# 195  205.254.127.151      US
# 196   127.202.178.51    none
# 197   89.133.124.168      HU
# 198   53.119.161.113      DE
# 199  240.174.206.196    none
#
# [200 rows x 2 columns]

# %%
pattCountryValueCount = pattIpCountry['country'].value_counts()
pattCountryValueCount
# Out:
# US      73
# none    29
# CN      20
# DE       9
# BR       7
# KR       6
# JP       5
# FR       4
# IN       3
# NL       3
# IT       3
# AU       3
# CH       2
# BE       2
# SE       2
# CA       2
# RU       2
# EG       2
# GB       2
# TW       2
# TR       2
# IE       1
# SG       1
# ZA       1
# ES       1
# DK       1
# PK       1
# VN       1
# HR       1
# IL       1
# IR       1
# MK       1
# MX       1
# MY       1
# BY       1
# VE       1
# HU       1
# PL       1
# Name: country, dtype: int64

# %% [markdown]
# ### value_counts를 통해 얻은 국가별 비율을 그래프로 그려보기

# %%
plt.figure(figsize=(12,12))
plt.pie(pattCountryValueCount.values, labels = pattCountryValueCount.index, autopct='%.1f%%')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(allCountryValueCount.values, labels = allCountryValueCount.index, autopct='%.1f%%')
plt.show()
